# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#credentials

c_id = 'b06e4aeb487047f3bbe6367899069473'
c_secret = '42a29f1408b24aadb8e8a7e12b9eeecf'

client_credentials_manager = SpotifyClientCredentials(client_id = c_id, client_secret = c_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#song data

import timeit
import time

start = timeit.default_timer()

artist_name = []
track_name = []
popularity = []
track_id = []

for i in range(0, 2000, 50):
    track_results = sp.search(q='year:2019 AND tag:hipster', limit=50, offset = i, market='US')
    
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        
stop = timeit.default_timer()
print('Run Time: ', stop - start)
track_results['tracks']
# Out:
# Run Time:  22.891946541000152
# {'href': 'https://api.spotify.com/v1/search?query=year%3A2019+AND+tag%3Ahipster&type=track&market=US&offset=1950&limit=50',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/48vVtpjXYUwaX03U1aIm0x'},
#       'href': 'https://api.spotify.com/v1/artists/48vVtpjXYUwaX03U1aIm0x',
#       'id': '48vVtpjXYUwaX03U1aIm0x',
#       'name': 'Piano Pianissimo',
#       'type': 'artist',
#       'uri': 'spotify:artist:48vVtpjXYUwaX03U1aIm0x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3JEJciEdxPP3Y77P7pp3A5'},
#     'href': 'https://api.spotify.com/v1/albums/3JEJciEdxPP3Y77P7pp3A5',
#     'id': '3JEJciEdxPP3Y77P7pp3A5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731b34d051953025f2b58c2036',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021b34d051953025f2b58c2036',
# ...
